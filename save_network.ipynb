# %%
import pandas as pd 
import networkx as nx
import pickle
from os import listdir
from os.path import isfile, join
import sys
import math
import ast
from datetime import datetime

# %%
politician_data = pd.read_csv("data/politician-data.csv",quotechar='"',sep="\t",converters=
                              {"occupation":ast.literal_eval})

# %%
def clean(x):
    """ Converts string to list
    """
    if type(x) == float:
        return []
    else: 
        return ast.literal_eval(x)

# %%
politician_data["party"] = politician_data["party"].apply(clean)

# %%
politician_data["nationality"] = politician_data["nationality"].apply(clean)

# %%
politician_data["name"] = politician_data["name"].apply(clean)

# %%
# politician_data

# %%
politician_data["birthDate"] = politician_data["birthDate"].apply(clean)

# %%
# politician_data["birthDate"] = politician_data["birthDate"].apply(clean)
# for i in politician_data["birthDate"].values:
#     for x in i:
#         if x in "-0106-01-03":
#             print(i)

# %%
def convert_date(date_lst):
    if date_lst == []:
        return None
    date = date_lst[0].strip(" ")
    try:
        date = datetime.strptime(date, '%Y-%m-%d')
        return date
    except:
#         print(date)
        return None

# %%
# politician_data["birthDate"] = politician_data["birthDate"].apply(clean)
politician_data["birthDate"] = politician_data["birthDate"].apply(convert_date)
# Out:
# -0106-01-03
# -0106-01-03
# -0106-09-29
# -0100-07-13
# -0106-01-03
# -0106-01-03

# %%
politician_data["deathDate"] = politician_data["deathDate"].apply(clean)

# %%
politician_data["deathDate"] = politician_data["deathDate"].apply(convert_date)
# Out:
# -0043-12-07
# -0043-12-07
# -0048-09-29
# -0044-03-15
# -0043-12-07
# -0043-12-07
# -0042-10-23

# %%
politician_data
# Out:
#                                                  #DBpURL       ID  \
# 0          http://dbpedia.org/resource/Quincy_Timberlake       11
# 1              http://dbpedia.org/resource/Fanny_Edelman       29
# 2           http://dbpedia.org/resource/Stojan_Novaković       65
# 3              http://dbpedia.org/resource/Paul_Scheffer      102
# 4                    http://dbpedia.org/resource/Ed_Robb      127
# 5          http://dbpedia.org/resource/Nizamettin_Erkmen      144
# 6            http://dbpedia.org/resource/Claudio_Scajola      183
# 7         http://dbpedia.org/resource/Lawrence_Lual_Lual      223
# 8      http://dbpedia.org/resource/Thomas_Clausen_(Lo...      246
# 9              http://dbpedia.org/resource/Yang_Ti-liang      248
# 10         http://dbpedia.org/resource/Georges_Colombier      252
# 11       http://dbpedia.org/resource/Gottlieb_Duttweiler      253
# 12           http://dbpedia.org/resource/Mohammad_Natsir      259
# 13                http://dbpedia.org/resource/Ján_Ševčík      272
# 14            http://dbpedia.org/resource/Georges_Othily      316
# 15     http://dbpedia.org/resource/Athanasios_N._Miao...      323
# 16      http://dbpedia.org/resource/Kristalina_Georgieva      396
# 17             http://dbpedia.org/resource/Otto_Hoetzsch      427
# 18        http://dbpedia.org/resource/Rafiq_Ahmed_Jamali      434
# 19           http://dbpedia.org/resource/Carolyn_Maloney      444
# 20     http://dbpedia.org/resource/Sir_Gilbert_Picker...      457
# 21              http://dbpedia.org/resource/Karel_Rüütli      462
# 22               http://dbpedia.org/resource/Todd_Rokita      483
# 23             http://dbpedia.org/resource/Salmir_Kaplan      521
# 24     http://dbpedia.org/resource/Ramón_Jiménez_Fuentes      524
# 25             http://dbpedia.org/resource/Krasen_Kralev      536
# 26             http://dbpedia.org/resource/Denver_Butler      546
# 27         http://dbpedia.org/resource/Massimo_Giorgetti      548
# 28              http://dbpedia.org/resource/Nancy_Shukri      583
# 29               http://dbpedia.org/resource/Julie_Green      594
# ...                                                  ...      ...
# 69149    http://dbpedia.org/resource/Ahmet_Zeki_Soydemir  1166878
# 69150        http://dbpedia.org/resource/Heinrich_Aigner  1166921
# 69151        http://dbpedia.org/resource/Josip_Broz_Tito  1166930
# 69152          http://dbpedia.org/resource/Hans_Amundsen  1166954
# 69153  http://dbpedia.org/resource/Josep_de_Suelves_i...  1166987
# 69154         http://dbpedia.org/resource/David_P._Lewis  1166990
# 69155  http://dbpedia.org/resource/Sir_James_Duncan,_...  1166994
# 69156          http://dbpedia.org/resource/Albert_Rollit  1167003
# 69157           http://dbpedia.org/resource/Kokou_Tozoun  1167012
# 69158     http://dbpedia.org/resource/Venturin_Thrauison  1167032
# 69159             http://dbpedia.org/resource/T._Sathiah  1167036
# 69160           http://dbpedia.org/resource/Walter_Ayles  1167046
# 69161            http://dbpedia.org/resource/Norah_Beare  1167051
# 69162  http://dbpedia.org/resource/Jacques_Antoine_Cr...  1167059
# 69163   http://dbpedia.org/resource/Sylvester_Perry_Ryan  1167066
# 69164            http://dbpedia.org/resource/Jeff_McCloy  1167074
# 69165  http://dbpedia.org/resource/Sir_Raymond_Greene...  1167091
# 69166  http://dbpedia.org/resource/Richard_Wesley,_1s...  1167125
# 69167            http://dbpedia.org/resource/Luo_Shaowei  1167126
# 69168       http://dbpedia.org/resource/Timothy_C._Evans  1167147
# 69169              http://dbpedia.org/resource/Li_Shidao  1167160
# 69170        http://dbpedia.org/resource/Toshio_Yamauchi  1167163
# 69171  http://dbpedia.org/resource/Rudolf_Arnold_Nieb...  1167170
# 69172          http://dbpedia.org/resource/Moses_Amweelo  1167194
# 69173     http://dbpedia.org/resource/Amarsinh_Chaudhary  1167202
# 69174  http://dbpedia.org/resource/Ole_Kristian_Kjølh...  1167212
# 69175          http://dbpedia.org/resource/John_F._Furey  1167220
# 69176     http://dbpedia.org/resource/James_Henry_McLean  1167224
# 69177         http://dbpedia.org/resource/Rudolf_Dassler  1167233
# 69178   http://dbpedia.org/resource/Raúl_Macías_Sandoval  1167254
#
#                                                  WikiURL  gender  \
# 0         http://en.wikipedia.org/wiki/Quincy_Timberlake    male
# 1             http://en.wikipedia.org/wiki/Fanny_Edelman  female
# 2          http://en.wikipedia.org/wiki/Stojan_Novaković     NaN
# 3             http://en.wikipedia.org/wiki/Paul_Scheffer    male
# 4                   http://en.wikipedia.org/wiki/Ed_Robb    male
# 5         http://en.wikipedia.org/wiki/Nizamettin_Erkmen    male
# 6           http://en.wikipedia.org/wiki/Claudio_Scajola    male
# 7        http://en.wikipedia.org/wiki/Lawrence_Lual_Lual     NaN
# 8      http://en.wikipedia.org/wiki/Thomas_Clausen_(L...    male
# 9             http://en.wikipedia.org/wiki/Yang_Ti-liang    male
# 10        http://en.wikipedia.org/wiki/Georges_Colombier    male
# 11      http://en.wikipedia.org/wiki/Gottlieb_Duttweiler    male
# 12          http://en.wikipedia.org/wiki/Mohammad_Natsir    male
# 13               http://en.wikipedia.org/wiki/Ján_Ševčík     NaN
# 14           http://en.wikipedia.org/wiki/Georges_Othily    male
# 15     http://en.wikipedia.org/wiki/Athanasios_N._Mia...    male
# 16     http://en.wikipedia.org/wiki/Kristalina_Georgieva  female
# 17            http://en.wikipedia.org/wiki/Otto_Hoetzsch    male
# 18       http://en.wikipedia.org/wiki/Rafiq_Ahmed_Jamali     NaN
# 19          http://en.wikipedia.org/wiki/Carolyn_Maloney  female
# 20     http://en.wikipedia.org/wiki/Sir_Gilbert_Picke...     NaN
# 21             http://en.wikipedia.org/wiki/Karel_Rüütli     NaN
# 22              http://en.wikipedia.org/wiki/Todd_Rokita    male
# 23            http://en.wikipedia.org/wiki/Salmir_Kaplan     NaN
# 24     http://en.wikipedia.org/wiki/Ramón_Jiménez_Fue...     NaN
# 25            http://en.wikipedia.org/wiki/Krasen_Kralev     NaN
# 26            http://en.wikipedia.org/wiki/Denver_Butler     NaN
# 27        http://en.wikipedia.org/wiki/Massimo_Giorgetti    male
# 28             http://en.wikipedia.org/wiki/Nancy_Shukri  female
# 29              http://en.wikipedia.org/wiki/Julie_Green  female
# ...                                                  ...     ...
# 69149   http://en.wikipedia.org/wiki/Ahmet_Zeki_Soydemir     NaN
# 69150       http://en.wikipedia.org/wiki/Heinrich_Aigner     NaN
# 69151       http://en.wikipedia.org/wiki/Josip_Broz_Tito    male
# 69152         http://en.wikipedia.org/wiki/Hans_Amundsen    male
# 69153  http://en.wikipedia.org/wiki/Josep_de_Suelves_...     NaN
# 69154        http://en.wikipedia.org/wiki/David_P._Lewis    male
# 69155  http://en.wikipedia.org/wiki/Sir_James_Duncan,...     NaN
# 69156         http://en.wikipedia.org/wiki/Albert_Rollit     NaN
# 69157          http://en.wikipedia.org/wiki/Kokou_Tozoun    male
# 69158    http://en.wikipedia.org/wiki/Venturin_Thrauison    male
# 69159            http://en.wikipedia.org/wiki/T._Sathiah    male
# 69160          http://en.wikipedia.org/wiki/Walter_Ayles    male
# 69161           http://en.wikipedia.org/wiki/Norah_Beare  female
# 69162  http://en.wikipedia.org/wiki/Jacques_Antoine_C...     NaN
# 69163  http://en.wikipedia.org/wiki/Sylvester_Perry_Ryan    male
# 69164           http://en.wikipedia.org/wiki/Jeff_McCloy    male
# 69165  http://en.wikipedia.org/wiki/Sir_Raymond_Green...     NaN
# 69166  http://en.wikipedia.org/wiki/Richard_Wesley,_1...     NaN
# 69167           http://en.wikipedia.org/wiki/Luo_Shaowei     NaN
# 69168      http://en.wikipedia.org/wiki/Timothy_C._Evans    male
# 69169             http://en.wikipedia.org/wiki/Li_Shidao     NaN
# 69170       http://en.wikipedia.org/wiki/Toshio_Yamauchi     NaN
# 69171  http://en.wikipedia.org/wiki/Rudolf_Arnold_Nie...    male
# 69172         http://en.wikipedia.org/wiki/Moses_Amweelo     NaN
# 69173    http://en.wikipedia.org/wiki/Amarsinh_Chaudhary    male
# 69174  http://en.wikipedia.org/wiki/Ole_Kristian_Kjøl...     NaN
# 69175         http://en.wikipedia.org/wiki/John_F._Furey     NaN
# 69176    http://en.wikipedia.org/wiki/James_Henry_McLean    male
# 69177        http://en.wikipedia.org/wiki/Rudolf_Dassler    male
# 69178  http://en.wikipedia.org/wiki/Raúl_Macías_Sandoval     NaN
#
#                                                     name            birthDate  \
# 0             [ quincy timberlake ,  timberlake quincy ]  1980-04-22 00:00:00
# 1                     [ fanny edelman ,  edelman fanny ]  1911-02-27 00:00:00
# 2      [ stojan novaković ,  (стојан новаковић) ,  st...  1842-11-01 00:00:00
# 3                                      [ scheffer paul ]  1954-09-03 00:00:00
# 4                                                     []                 None
# 5                                  [ erkmen nizamettin ]                 None
# 6                                    [ claudio scajola ]  1948-01-15 00:00:00
# 7                                 [ lawrence lual lual ]                 None
# 8      [ thomas greenwood clausen ,  clausen thomas g...  1939-12-22 00:00:00
# 9                                      [ ti-liang yang ]  1929-06-30 00:00:00
# 10                                 [ colombier georges ]  1940-03-08 00:00:00
# 11                               [ gottlieb duttweiler ]  1888-08-18 00:00:00
# 12                [ mohammad natsir ,  natsir mohammad ]  1908-07-17 00:00:00
# 13                                        [ sevcik jan ]  1896-02-13 00:00:00
# 14                                    [ othily georges ]  1944-01-07 00:00:00
# 15     [ athanasios n miaoulis ,  αθανάσιος ν μιαούλη...                 None
# 16      [ kristalina georgieva ,  georgieva kristalina ]  1953-08-13 00:00:00
# 17                                     [ hoetzsch otto ]  1876-02-14 00:00:00
# 18                                [ rafiq ahmed jamali ]  1967-12-25 00:00:00
# 19                                   [ carolyn maloney ]  1946-02-19 00:00:00
# 20                                 [ pickering gilbert ]                 None
# 21                                      [ ruutli karel ]                 None
# 22                                       [ todd rokita ]  1970-02-09 00:00:00
# 23                    [ salmir kaplan ,  kaplan salmir ]  1981-06-26 00:00:00
# 24            [ ramón jiménez fuentes ,  jimenez ramon ]  1955-12-01 00:00:00
# 25                    [ krasen kralev ,  kralev krasen ]  1967-01-02 00:00:00
# 26                                     [ denver butler ]  1970-04-01 00:00:00
# 27                                 [ giorgetti massimo ]  1959-10-20 00:00:00
# 28                      [ nancy shukri ,  shukri nancy ]  1961-08-05 00:00:00
# 29                                       [ julie green ]                 None
# ...                                                  ...                  ...
# 69149  [ ahmet zeki soydemir ,  1321-p5 ,  soydemir a...                 None
# 69150                                [ aigner heinrich ]  1924-05-25 00:00:00
# 69151                                [ josip broz tito ]  1892-05-07 00:00:00
# 69152                                  [ amundsen hans ]  1885-03-23 00:00:00
# 69153                 [ josep de suelves i de montagut ]                 None
# 69154                                  [ david p lewis ]                 None
# 69155                                   [ duncan james ]                 None
# 69156                             [ rollit albert kaye ]                 None
# 69157                                   [ tozoun kokou ]                 None
# 69158                             [ thrauison venturin ]                 None
# 69159                                      [ sathiah t ]                 None
# 69160             [ walter ayles ,  ayles walter henry ]  1879-04-24 00:00:00
# 69161                                    [ norah beare ]  1946-05-25 00:00:00
# 69162                [ jacques antoine creuzé-latouche ]  1749-09-18 00:00:00
# 69163             [ sylvester perry ryan ,  ryan perry ]  1918-01-12 00:00:00
# 69164                     [ jeff mccloy ,  mccloy jeff ]                 None
# 69165                                  [ greene walter ]  1869-08-04 00:00:00
# 69166     [ wesley richard colley 1st baron mornington ]                 None
# 69167                                    [ luo shaowei ]                 None
# 69168                                [ timothy c evans ]  1943-06-01 00:00:00
# 69169                                      [ li shidao ]                 None
# 69170                                [ yamauchi toshio ]                 None
# 69171  [ rudolf arnold nieberding ,  nieberding rudol...  1838-05-04 00:00:00
# 69172                                  [ amweelo moses ]  1952-05-25 00:00:00
# 69173                             [ amarsinh chaudhary ]  1941-07-31 00:00:00
# 69174                        [ kjoelholdt ole kristian ]  1950-09-08 00:00:00
# 69175                                   [ furey john f ]  1906-04-08 00:00:00
# 69176                             [ mclean james henry ]  1829-08-13 00:00:00
# 69177                                 [ rudolf dassler ]  1898-03-26 00:00:00
# 69178            [ raúl macías sandoval ,  macias raul ]  1942-09-22 00:00:00
#
#                  deathDate                                         occupation  \
# 0                     None                                       [politician]
# 1      2011-11-01 00:00:00                                       [politician]
# 2      1915-02-18 00:00:00       [historian, philology, politician, diplomat]
# 3                     None                                       [politician]
# 4                     None                                       [politician]
# 5      1990-10-24 00:00:00                                       [politician]
# 6                     None                                       [politician]
# 7                     None                                       [politician]
# 8      2002-02-20 00:00:00                                       [politician]
# 9                     None                                       [politician]
# 10                    None                                       [politician]
# 11     1962-06-08 00:00:00                       [businessperson, politician]
# 12     1993-03-14 00:00:00                                       [politician]
# 13     1965-03-06 00:00:00                                       [politician]
# 14                    None                               [politician, writer]
# 15                    None                                       [politician]
# 16                    None                 [politician, economist, scientist]
# 17     1946-08-27 00:00:00                                       [politician]
# 18                    None                                       [politician]
# 19                    None                               [politician, writer]
# 20                    None                                       [politician]
# 21                    None                                       [politician]
# 22                    None                                       [politician]
# 23                    None                                       [politician]
# 24                    None                                       [politician]
# 25                    None                                       [politician]
# 26                    None                                       [politician]
# 27                    None                                       [politician]
# 28                    None                                       [politician]
# 29                    None                                       [politician]
# ...                    ...                                                ...
# 69149  1954-09-04 00:00:00  [member of parliament, çankırı province, polit...
# 69150  1988-03-24 00:00:00                                       [politician]
# 69151  1980-05-04 00:00:00  [machinist, revolutionary, resistance during w...
# 69152  1967-05-05 00:00:00                   [journalist, writer, politician]
# 69153                 None                                       [politician]
# 69154  1884-07-03 00:00:00                                       [politician]
# 69155  1974-09-30 00:00:00                                       [politician]
# 69156  1922-08-12 00:00:00                                       [politician]
# 69157                 None                                       [politician]
# 69158                 None                                       [politician]
# 69159                 None                                       [politician]
# 69160  1953-07-06 00:00:00                                       [politician]
# 69161                 None                                       [politician]
# 69162  1800-10-23 00:00:00                    [lawyer politician, politician]
# 69163  2001-10-23 00:00:00                                       [politician]
# 69164                 None                             [engineer, politician]
# 69165  1947-08-24 00:00:00                                       [politician]
# 69166  1758-01-31 00:00:00                                       [politician]
# 69167                 None                                       [politician]
# 69168                 None                                       [politician]
# 69169                 None                                       [politician]
# 69170                 None                                       [politician]
# 69171  1912-10-10 00:00:00                                       [politician]
# 69172                 None                                       [politician]
# 69173  2004-08-15 00:00:00                                       [politician]
# 69174                 None                                       [politician]
# 69175  1973-12-21 00:00:00                                       [politician]
# 69176  1886-08-12 00:00:00                                       [politician]
# 69177  1974-10-27 00:00:00       [entrepreneurship, entrepreneur, politician]
# 69178                 None                               [deputy, politician]
#
#                     nationality  \
# 0                      [kenyan]
# 1                   [argentine]
# 2                     [serbian]
# 3                            []
# 4                    [american]
# 5                     [turkish]
# 6                     [italian]
# 7      [dinka people, sudanese]
# 8                    [american]
# 9                            []
# 10                     [french]
# 11                      [swiss]
# 12                 [indonesian]
# 13                     [slovak]
# 14                     [french]
# 15                      [greek]
# 16                  [bulgarian]
# 17                     [german]
# 18                  [pakistani]
# 19                   [american]
# 20                           []
# 21                   [estonian]
# 22                   [american]
# 23                   [bosniaks]
# 24                    [mexican]
# 25                  [bulgarian]
# 26                   [american]
# 27                           []
# 28                  [malaysian]
# 29                   [canadian]
# ...                         ...
# 69149     [macedonian, turkish]
# 69150                        []
# 69151                [croatian]
# 69152               [norwegian]
# 69153      [spaniards, spanish]
# 69154                [american]
# 69155                        []
# 69156                        []
# 69157                [togolese]
# 69158                        []
# 69159                        []
# 69160                 [british]
# 69161                        []
# 69162                  [french]
# 69163                        []
# 69164              [australian]
# 69165                        []
# 69166                   [irish]
# 69167                        []
# 69168                        []
# 69169                        []
# 69170                        []
# 69171                  [german]
# 69172                        []
# 69173                  [indian]
# 69174                        []
# 69175                        []
# 69176                        []
# 69177                  [german]
# 69178                        []
#
#                                                    party
# 0                                                     []
# 1                                                     []
# 2             [ serbian progressive party (historical) ]
# 3                                                     []
# 4                                                     []
# 5                                                     []
# 6                                [ forza italia (2013) ]
# 7                          [ national congress (sudan) ]
# 8                   [ democratic party (united states) ]
# 9                                                     []
# 10                      [ union for a popular movement ]
# 11                          [ alliance of independents ]
# 12                                     [ masyumi party ]
# 13                                                    []
# 14                                                    []
# 15                                                    []
# 16                                              [ gerb ]
# 17                                                    []
# 18                            [ pakistan peoples party ]
# 19                  [ democratic party (united states) ]
# 20                                                    []
# 21                                                    []
# 22                  [ republican party (united states) ]
# 23                        [ party of democratic action ]
# 24                                                    []
# 25                                                    []
# 26     [ republican party (united states) ,  democrat...
# 27                                                    []
# 28                   [ parti pesaka bumiputera bersatu ]
# 29                    [ consensus government in canada ]
# ...                                                  ...
# 69149                                                 []
# 69150                                                 []
# 69151  [ communist party of the soviet union ,  leagu...
# 69152                                                 []
# 69153                                        [ carlism ]
# 69154               [ republican party (united states) ]
# 69155                                                 []
# 69156                                                 []
# 69157                                                 []
# 69158                                                 []
# 69159                                                 []
# 69160                              [ labour party (uk) ]
# 69161                      [ democratic unionist party ]
# 69162                                                 []
# 69163  [ liberal party of canada ,  progressive conse...
# 69164                         [ independent politician ]
# 69165                                                 []
# 69166                                                 []
# 69167                                                 []
# 69168               [ democratic party (united states) ]
# 69169                                                 []
# 69170                                                 []
# 69171                                                 []
# 69172                                                 []
# 69173                       [ indian national congress ]
# 69174                                                 []
# 69175                                                 []
# 69176                                                 []
# 69177                                                 []
# 69178                                                 []
#
# [69179 rows x 10 columns]

# %%
politician_data.to_json("data/politician-data.json")

# %%
def get_files(path):
    """ Returns a list of files in a directory
        Input parameter: path to directory
    """
    mypath = path
    complete = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    return complete

# %%
files = get_files("data/filtered_edge_list")

# %%
def load_df(path, file):
    """ Loads a csv file, returns a dataframe
        Input parameters:
        1. path - to directory containing a file
        2. file - name of the file
    """
    return pd.read_csv(path+"/"+file)

# %%
# net = load_df("data/filtered_edge_list/",files[7])

# %%
# net

# %%
# G = nx.from_pandas_dataframe(net,'from','to')

# %%
# len(G.nodes())
# node_list = G.nodes()
# data = politician_data[politician_data["ID"].isin(node_list)]
# name_data = data[["ID","name"]].set_index('ID')['name'].to_dict()
# gender_data = data[["ID","gender"]].set_index('ID')['gender'].to_dict()
# occupation_data = data[["ID","occupation"]].set_index('ID')['occupation'].to_dict()
# nationality_data = data[["ID","nationality"]].set_index('ID')['nationality'].to_dict()
# party_data = data[["ID","party"]].set_index('ID')['party'].to_dict()

# %%
def set_attributes(dataframe, attribute_dataframe, graph_type = 'dir'):
    """ Returns a network with attributes assigned to each node
        Input parameters:
        1. dataframe - edge list
        2. attribute_dataframe - contains node id, and attributes (name, parrty, nationality, occupation, gender)
        3. graph_type - 'dir' or 'undir'
    """
    
    # load dataframe as graph
    if graph_type == 'dir':
        G = nx.from_pandas_dataframe(dataframe,'from','to', edge_attr=False, create_using=nx.DiGraph())
    elif graph_type == 'undir':
        G = nx.from_pandas_dataframe(dataframe,'from','to', edge_attr=False, create_using=nx.Graph())
    
    
#     G = nx.from_pandas_dataframe(dataframe,'from','to')
    # get list of nodes
    node_list = G.nodes()
    # create dictionaries
    data = attribute_dataframe[attribute_dataframe["ID"].isin(node_list)]
    name_data = data[["ID","name"]].set_index('ID')['name'].to_dict()
    gender_data = data[["ID","gender"]].set_index('ID')['gender'].to_dict()
    occupation_data = data[["ID","occupation"]].set_index('ID')['occupation'].to_dict()
    nationality_data = data[["ID","nationality"]].set_index('ID')['nationality'].to_dict()
    party_data = data[["ID","party"]].set_index('ID')['party'].to_dict()
    # set attributes 
    nx.set_node_attributes(G, 'gender', gender_data)
    nx.set_node_attributes(G, 'name', name_data)
    nx.set_node_attributes(G, 'occupation', occupation_data)
    nx.set_node_attributes(G, 'nationality', nationality_data)
    nx.set_node_attributes(G, 'party', party_data)
    
    #print stuff
    num_n = len(G.nodes())
    num_e = len(G.edges())
    print("Number of nodes: ", num_n)
    print("Number of edges: ", num_e)
    
    return G, num_n, num_e

# %%
# output: 
# G.node[606]
# {'gender': 'male',
#  'name': [' brice lalonde '],
#  'nationality': ['french'],
#  'occupation': ['politician'],
#  'party': []}

# %%
# nx.write_gpickle(G,"data/graphs/x")

# %%
# k = nx.read_gpickle("data/graphs/x")

# %%
def save_network(G, path_save,file, sufix=""):
    """ Saves network on specified path as PICKLE
        Input parameters:
        1. Graph
        2. path_save - path to directory
        3. file name
        4. sufix - 'dir' for example 
    """
    print("Network saved as pickle on PATH: ", path_save+"/"+file)
    nx.write_gpickle(G,path_save+"/"+file+sufix)

# %%
# lst = []
# for file in files[:5]:
#     print(file)
#     net_df = load_df("data/filtered_edge_list",file)
#     G, num_n, num_e = set_attributes(net_df, politician_data)
#     sub_lst = [file,num_n, num_e]
#     lst.append(sub_lst)
#     save_network(G,"data/graphs",file.replace(".csv",""))
# df = pd.DataFrame(lst)
# df.columns = ["file","nodes","edges"]
# df.to_csv("data/graphs/stats.csv")

# %%
# net_df = load_df("data/filtered_edge_list","2003_06.csv")
# G, num_n, num_e = set_attributes(net_df, politician_data,'undir')
# Out:
# Number of nodes:  954
# Number of edges:  1123

# %%
# type(G)

# %%
# G = nx.DiGraph()

# %%
# G.is_directed()
